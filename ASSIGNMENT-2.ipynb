# %%
list_1_states=['Andaman and Nicobar','Andhra Pradesh','Arunachal Pradesh','Assam','Bihar','Chandigarh','Chhattisgarh','Dadra and Nagar Haveli and Daman'
,'Daman and Diu','Delhi','Goa','Gujarat','Haryana','Himachal Pradesh','Jammu and Kashmir','Jharkhand','Karnataka','Kerala','Ladakh'
,'Lakshadweep','Madhya Pradesh','Maharashtra','Manipur','Meghalaya','Mizoram','Nagaland','Odisha','Puducherry','Punjab','Rajasthan'
,'Sikkim','Tamil Nadu','Telengana','Tripura','Uttar Pradesh','Uttarakhand','West Bengal']

list_2_confirmed_cases=[194,40646,609,20646,23589,660,4964,585,0,120107,3304,46430,24797,1417,12757,4921,55115,11066,1151,0,21081
,292589,1800,403,282,956,16110,1832,9442,27789,266,160907,42496,2366,45163,4102,38011]

list_3_recovered_cases=[142,20298,175,14105,14621,480,3512,401,0,99301,1946,32973,18718,1024,6558,2570,20757,4995,973,0,14514
,160357,1163,66,160,405,11330,1014,6373,20626,90,110807,28705,1684,27634,3021,22253]

list_5_number_of_deaths=[0,534,3,51,201,11,23,2,0,3571,21,2106,327,11,231,46,1147,38,1,0,697,11452,0,2,0,0,83,25,239,546,0,2315,403
,3,1084,51,1049]

list_6_population_in_each_state=[380581,84580777,1383727,31205576,104099452,1055450,25545198,343709,243247,1458545,60439692,25351462
,6864602,9944283,32988134,61095297,33406061,290492,64473,72626809,112374333,2855794,2966889,1097206,1978502,16787941,41974218,1247953
,27743338,68548437,610577,72147030,35193978,3673917,199812341,10086292,91276115]

list_7_active_cases=[52,19814,431,6490,8767,169,1429,182,0,17235,1337,11351,5752,382,5968,2305,33211,6033,177,0,5870,120780,637,335,
122,551,4697,793,2830,6617,176,47785,13388,679,16445,1030,14709]

# %%
print('(STATES , RECOVERED)')
for i in range(len(list_1_states)):
        list_4_recovered_statewise=[(list_1_states[i],list_3_recovered_cases[i])]
        for i in list_4_recovered_statewise:
            print(i)
# Out:
# (STATES , RECOVERED)
# ('Andaman and Nicobar', 142)
# ('Andhra Pradesh', 20298)
# ('Arunachal Pradesh', 175)
# ('Assam', 14105)
# ('Bihar', 14621)
# ('Chandigarh', 480)
# ('Chhattisgarh', 3512)
# ('Dadra and Nagar Haveli and Daman', 401)
# ('Daman and Diu', 0)
# ('Delhi', 99301)
# ('Goa', 1946)
# ('Gujarat', 32973)
# ('Haryana', 18718)
# ('Himachal Pradesh', 1024)
# ('Jammu and Kashmir', 6558)
# ('Jharkhand', 2570)
# ('Karnataka', 20757)
# ('Kerala', 4995)
# ('Ladakh', 973)
# ('Lakshadweep', 0)
# ('Madhya Pradesh', 14514)
# ('Maharashtra', 160357)
# ('Manipur', 1163)
# ('Meghalaya', 66)
# ('Mizoram', 160)
# ('Nagaland', 405)
# ('Odisha', 11330)
# ('Puducherry', 1014)
# ('Punjab', 6373)
# ('Rajasthan', 20626)
# ('Sikkim', 90)
# ('Tamil Nadu', 110807)
# ('Telengana', 28705)
# ('Tripura', 1684)
# ('Uttar Pradesh', 27634)
# ('Uttarakhand', 3021)
# ('West Bengal', 22253)

# %%
for i in range(len(list_1_states)):
   dict_total_INFECTED_cases = {list_1_states[i]:list_2_confirmed_cases[i]}
   print(dict_total_INFECTED_cases)
# Out:
# {'Andaman and Nicobar': 194}
# {'Andhra Pradesh': 40646}
# {'Arunachal Pradesh': 609}
# {'Assam': 20646}
# {'Bihar': 23589}
# {'Chandigarh': 660}
# {'Chhattisgarh': 4964}
# {'Dadra and Nagar Haveli and Daman': 585}
# {'Daman and Diu': 0}
# {'Delhi': 120107}
# {'Goa': 3304}
# {'Gujarat': 46430}
# {'Haryana': 24797}
# {'Himachal Pradesh': 1417}
# {'Jammu and Kashmir': 12757}
# {'Jharkhand': 4921}
# {'Karnataka': 55115}
# {'Kerala': 11066}
# {'Ladakh': 1151}
# {'Lakshadweep': 0}
# {'Madhya Pradesh': 21081}
# {'Maharashtra': 292589}
# {'Manipur': 1800}
# {'Meghalaya': 403}
# {'Mizoram': 282}
# {'Nagaland': 956}
# {'Odisha': 16110}
# {'Puducherry': 1832}
# {'Punjab': 9442}
# {'Rajasthan': 27789}
# {'Sikkim': 266}
# {'Tamil Nadu': 160907}
# {'Telengana': 42496}
# {'Tripura': 2366}
# {'Uttar Pradesh': 45163}
# {'Uttarakhand': 4102}
# {'West Bengal': 38011}

# %%
#function to calculate IFR 
def IFR(infected,deaths):
    if(infected!=0):
        ifr=(deaths/infected)*100
    else:
        ifr=0.0
    print("IFR ={}%".format(ifr))

#IFR values for every state
for i in range (len(list_1_states)):
    print(list_1_states[i])
    IFR(list_2_confirmed_cases[i],list_5_number_of_deaths[i])
# Out:
# Andaman and Nicobar
# IFR =0.0%
# Andhra Pradesh
# IFR =1.3137824140136791%
# Arunachal Pradesh
# IFR =0.49261083743842365%
# Assam
# IFR =0.24702121476315023%
# Bihar
# IFR =0.8520920768154648%
# Chandigarh
# IFR =1.6666666666666667%
# Chhattisgarh
# IFR =0.46333601933924257%
# Dadra and Nagar Haveli and Daman
# IFR =0.3418803418803419%
# Daman and Diu
# IFR =0.0%
# Delhi
# IFR =2.9731822458308006%
# Goa
# IFR =0.6355932203389831%
# Gujarat
# IFR =4.535860435063537%
# Haryana
# IFR =1.3187079082147033%
# Himachal Pradesh
# IFR =0.776287932251235%
# Jammu and Kashmir
# IFR =1.8107705573410675%
# Jharkhand
# IFR =0.9347693558219874%
# Karnataka
# IFR =2.0811031479633493%
# Kerala
# IFR =0.34339418037231156%
# Ladakh
# IFR =0.08688097306689835%
# Lakshadweep
# IFR =0.0%
# Madhya Pradesh
# IFR =3.3062947678003893%
# Maharashtra
# IFR =3.9140227417982216%
# Manipur
# IFR =0.0%
# Meghalaya
# IFR =0.49627791563275436%
# Mizoram
# IFR =0.0%
# Nagaland
# IFR =0.0%
# Odisha
# ...

# %%
#function to calculate CMR
def CMR(deaths,population):
    cmr=(deaths/population)*100000
    print("The Crude Mortality Rate = {}%".format(cmr))

#CMR values for every state
for i in range (len(list_1_states)):
    print(list_1_states[i])
    CMR(list_5_number_of_deaths[i],list_6_population_in_each_state[i])
# Out:
# Andaman and Nicobar
# The Crude Mortality Rate = 0.0%
# Andhra Pradesh
# The Crude Mortality Rate = 0.6313491303112527%
# Arunachal Pradesh
# The Crude Mortality Rate = 0.2168057716587159%
# Assam
# The Crude Mortality Rate = 0.16343233017073616%
# Bihar
# The Crude Mortality Rate = 0.19308458991695746%
# Chandigarh
# The Crude Mortality Rate = 1.0422094841063054%
# Chhattisgarh
# The Crude Mortality Rate = 0.0900364913985008%
# Dadra and Nagar Haveli and Daman
# The Crude Mortality Rate = 0.5818875851374273%
# Daman and Diu
# The Crude Mortality Rate = 0.0%
# Delhi
# The Crude Mortality Rate = 244.83303566225243%
# Goa
# The Crude Mortality Rate = 0.03474537891424066%
# Gujarat
# The Crude Mortality Rate = 8.307213209242134%
# Haryana
# The Crude Mortality Rate = 4.7635682301756175%
# Himachal Pradesh
# The Crude Mortality Rate = 0.11061632095546758%
# Jammu and Kashmir
# The Crude Mortality Rate = 0.7002517935691664%
# Jharkhand
# The Crude Mortality Rate = 0.07529221111733035%
# ...

# %%
print("(STATES , ACTIVE , RECOVERED , DECEASED)")
for i in range(len(list_1_states)):
    list_8_infected_data=[(list_1_states[i] , list_7_active_cases[i] , list_3_recovered_cases[i] , list_5_number_of_deaths[i])]
    for i in (list_8_infected_data):
        print(i)
# Out:
# (STATES , ACTIVE , RECOVERED , DECEASED)
# ('Andaman and Nicobar', 52, 142, 0)
# ('Andhra Pradesh', 19814, 20298, 534)
# ('Arunachal Pradesh', 431, 175, 3)
# ('Assam', 6490, 14105, 51)
# ('Bihar', 8767, 14621, 201)
# ('Chandigarh', 169, 480, 11)
# ('Chhattisgarh', 1429, 3512, 23)
# ('Dadra and Nagar Haveli and Daman', 182, 401, 2)
# ('Daman and Diu', 0, 0, 0)
# ('Delhi', 17235, 99301, 3571)
# ('Goa', 1337, 1946, 21)
# ('Gujarat', 11351, 32973, 2106)
# ('Haryana', 5752, 18718, 327)
# ('Himachal Pradesh', 382, 1024, 11)
# ('Jammu and Kashmir', 5968, 6558, 231)
# ('Jharkhand', 2305, 2570, 46)
# ('Karnataka', 33211, 20757, 1147)
# ('Kerala', 6033, 4995, 38)
# ('Ladakh', 177, 973, 1)
# ('Lakshadweep', 0, 0, 0)
# ('Madhya Pradesh', 5870, 14514, 697)
# ('Maharashtra', 120780, 160357, 11452)
# ('Manipur', 637, 1163, 0)
# ('Meghalaya', 335, 66, 2)
# ('Mizoram', 122, 160, 0)
# ('Nagaland', 551, 405, 0)
# ('Odisha', 4697, 11330, 83)
# ('Puducherry', 793, 1014, 25)
# ('Punjab', 2830, 6373, 239)
# ...
